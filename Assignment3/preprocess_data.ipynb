# %%
import torch.nn as nn
import librosa
import numpy as np
import torch
import torch.utils.data
import matplotlib.pyplot as plt
import IPython.display as ipd
import os

# %%
# from google.colab import drive
# drive.mount('/content/drive/')

# os.chdir('/content/drive/My Drive/Colab Notebooks')

# %%
training_folder = 'tr'
validation_folder = 'v'
test_folder = 'te'
file_extension = '.wav'
dimension = 513
file_count_to_denoise = 1200
epochs = 300
srx = None
srn = None
srs = None
save_files = True

# %%
def get_file_number(number):
    return "0" * (4 - len(number)) + number + file_extension

# %%
def file_exists(file):
  return os.path.isfile(file)

# %%
def get_files(folder, test=False):
  dirty_files = []
  speech_files = []
  noise_files = []
  for i in range(file_count_to_denoise):
      dirty_files.append(folder+'/' + folder + 'x'  + get_file_number(str(i)))
      if not test:
        speech_files.append(folder+'/' + folder +'s' + get_file_number(str(i)))
        noise_files.append(folder+ '/' + folder + 'n' + get_file_number(str(i)))
  if not test:
    return dirty_files, speech_files, noise_files
  return dirty_files

# %%
if file_exists('train_dirty_files'):
  print('Loading existing files')
  train_dirty_files = np.load('train_dirty_files')

if file_exists('train_speech_files'):
  train_dirty_files = np.load('train_speech_files')

if file_exists('train_noise_files'):
  train_dirty_files = np.load('train_noise_files')
else:
  train_dirty_files, train_speech_files, train_noise_files = get_files(training_folder)
  
if save_files:
  np.save('train_dirty_files', train_dirty_files)
  np.save('train_speech_files', train_speech_files)
  np.save('train_noise_files', train_noise_files)
 
# test_dirty_files, test_speech_files, test_noise_files = get_files(test_folder)

# %%
def get_processed_lists(dirty_files, speech_files, noise_files, test=False):
  x_list = np.zeros(shape=(dimension,1))
  x_complex = np.zeros(shape=(dimension,1))
  if not test:
    s_list = np.zeros(shape=(dimension,1))
    n_list = np.zeros(shape=(dimension,1))
  
  global srs
  global srx
  global srn
  for i in range(file_count_to_denoise):
      print("Running for tile", str(i))
  #     for dirty files
      x, srx=librosa.load(dirty_files[i], sr=None)
      X=librosa.stft(x, n_fft=1024, hop_length=512)
  #     for speech files
      if not test:
        s, srs=librosa.load(speech_files[i], sr=None)
        S=librosa.stft(s, n_fft=1024, hop_length=512)
    #     for noise files
        n, srn=librosa.load(noise_files[i], sr=None)
        N=librosa.stft(n, n_fft=1024, hop_length=512)
      
      
      x_abs = np.abs(X)
      if not test:
        s_abs = np.abs(S)
        n_abs = np.abs(N)
      
      if x_list.shape[1] == 1:
          x_list = x_abs
          x_complex = X
          if not test:
            s_list = s_abs
            n_list = n_abs
      else:  
          x_list = np.append(x_list, x_abs,1)
          x_complex = np.append(x_complex, X, 1)
          if not test:
            s_list = np.append(s_list, s_abs,1)
            n_list = np.append(n_list, n_abs,1)

      x_list = np.append(x_list, x_abs, 1)
      x_complex = np.append(x_complex, X, 1)
      if not test:
        s_list = np.append(s_list, s_abs,1)
        n_list = np.append(n_list, n_abs,1)
  x_list = x_list.T
  x_complex = x_complex.T
  
  if not test:
    n_list = n_list.T
    s_list = s_list.T
   
  if not test:
    return s_list,n_list,x_list, x_complex
  return x_list, x_complex

# %%
if file_exists('train_s_list'):
  print('Loading existing files')
  train_s_list = np.load('train_s_list')

if file_exists('train_n_list'):
  train_n_list = np.load('train_n_list')

if file_exists('train_x_list'):
  train_x_list = np.load('train_x_list')
  
if file_exists('train_x_complex'):
  train_x_complex = np.load('train_x_complex')
else:
  train_s_list, train_n_list, train_x_list, train_x_complex = get_processed_lists(train_dirty_files, train_speech_files, train_noise_files)
  
if save_files:
  np.save('train_s_list', train_s_list)
  np.save('train_n_list', train_n_list)
  np.save('train_x_list', train_x_list)
  np.save('train_x_complex', train_x_complex)
# Out:
# Running for tile 0
# Running for tile 1
# Running for tile 2
# Running for tile 3
# Running for tile 4
# Running for tile 5
# Running for tile 6
# Running for tile 7
# Running for tile 8
# Running for tile 9
# Running for tile 10
# Running for tile 11
# Running for tile 12
# Running for tile 13
# Running for tile 14
# Running for tile 15
# Running for tile 16
# Running for tile 17
# Running for tile 18
# Running for tile 19
# Running for tile 20
# Running for tile 21
# Running for tile 22
# Running for tile 23
# Running for tile 24
# Running for tile 25
# Running for tile 26
# Running for tile 27
# Running for tile 28
# Running for tile 29
# Running for tile 30
# Running for tile 31
# Running for tile 32
# Running for tile 33
# Running for tile 34
# Running for tile 35
# Running for tile 36
# Running for tile 37
# Running for tile 38
# Running for tile 39
# Running for tile 40
# Running for tile 41
# Running for tile 42
# Running for tile 43
# Running for tile 44
# Running for tile 45
# Running for tile 46
# Running for tile 47
# Running for tile 48
# Running for tile 49
# Running for tile 50
# Running for tile 51
# Running for tile 52
# Running for tile 53
# Running for tile 54
# Running for tile 55
# Running for tile 56
# Running for tile 57
# Running for tile 58
# Running for tile 59
# Running for tile 60
# Running for tile 61
# Running for tile 62
# Running for tile 63
# Running for tile 64
# Running for tile 65
# Running for tile 66
# Running for tile 67
# Running for tile 68
# Running for tile 69
# Running for tile 70
# Running for tile 71
# Running for tile 72
# Running for tile 73
# Running for tile 74
# Running for tile 75
# Running for tile 76
# Running for tile 77
# Running for tile 78
# Running for tile 79
# Running for tile 80
# Running for tile 81
# Running for tile 82
# Running for tile 83
# Running for tile 84
# Running for tile 85
# Running for tile 86
# Running for tile 87
# Running for tile 88
# Running for tile 89
# Running for tile 90
# Running for tile 91
# Running for tile 92
# Running for tile 93
# Running for tile 94
# Running for tile 95
# Running for tile 96
# Running for tile 97
# Running for tile 98
# Running for tile 99
# Running for tile 100
# Running for tile 101
# Running for tile 102
# Running for tile 103
# Running for tile 104
# Running for tile 105
# Running for tile 106
# Running for tile 107
# Running for tile 108
# Running for tile 109
# Running for tile 110
# Running for tile 111
# Running for tile 112
# Running for tile 113
# Running for tile 114
# Running for tile 115
# Running for tile 116
# Running for tile 117
# Running for tile 118
# Running for tile 119
# Running for tile 120
# Running for tile 121
# Running for tile 122
# Running for tile 123
# Running for tile 124
# Running for tile 125
# Running for tile 126
# Running for tile 127
# Running for tile 128
# Running for tile 129
# Running for tile 130
# Running for tile 131
# Running for tile 132
# Running for tile 133
# Running for tile 134
# Running for tile 135
# Running for tile 136
# Running for tile 137
# Running for tile 138
# Running for tile 139
# Running for tile 140
# Running for tile 141
# Running for tile 142
# Running for tile 143
# Running for tile 144
# Running for tile 145
# Running for tile 146
# Running for tile 147
# Running for tile 148
# Running for tile 149
# Running for tile 150
# Running for tile 151
# Running for tile 152
# Running for tile 153
# Running for tile 154
# Running for tile 155
# Running for tile 156
# Running for tile 157
# Running for tile 158
# Running for tile 159
# Running for tile 160
# Running for tile 161
# Running for tile 162
# Running for tile 163
# Running for tile 164
# Running for tile 165
# Running for tile 166
# Running for tile 167
# Running for tile 168
# Running for tile 169
# Running for tile 170
# Running for tile 171
# Running for tile 172
# Running for tile 173
# Running for tile 174
# Running for tile 175
# Running for tile 176
# Running for tile 177
# Running for tile 178
# Running for tile 179
# Running for tile 180
# Running for tile 181
# Running for tile 182
# Running for tile 183
# Running for tile 184
# Running for tile 185
# Running for tile 186
# Running for tile 187
# Running for tile 188
# Running for tile 189
# Running for tile 190
# Running for tile 191
# Running for tile 192
# Running for tile 193
# Running for tile 194
# Running for tile 195
# Running for tile 196
# Running for tile 197
# Running for tile 198
# Running for tile 199
# Running for tile 200
# Running for tile 201
# Running for tile 202
# Running for tile 203
# Running for tile 204
# Running for tile 205
# Running for tile 206
# Running for tile 207
# Running for tile 208
# Running for tile 209
# Running for tile 210
# Running for tile 211
# Running for tile 212
# Running for tile 213
# Running for tile 214
# Running for tile 215
# Running for tile 216
# Running for tile 217
# Running for tile 218
# Running for tile 219
# Running for tile 220
# Running for tile 221
# Running for tile 222
# Running for tile 223
# Running for tile 224
# Running for tile 225
# Running for tile 226
# Running for tile 227
# Running for tile 228
# Running for tile 229
# Running for tile 230
# Running for tile 231
# Running for tile 232
# Running for tile 233
# Running for tile 234
# Running for tile 235
# Running for tile 236
# Running for tile 237
# Running for tile 238
# Running for tile 239
# Running for tile 240
# Running for tile 241
# Running for tile 242
# Running for tile 243
# Running for tile 244
# Running for tile 245
# Running for tile 246
# Running for tile 247
# Running for tile 248
# Running for tile 249
# Running for tile 250
# Running for tile 251
# Running for tile 252
# Running for tile 253
# Running for tile 254
# Running for tile 255
# Running for tile 256
# Running for tile 257
# Running for tile 258
# Running for tile 259
# Running for tile 260
# Running for tile 261
# Running for tile 262
# Running for tile 263
# Running for tile 264
# Running for tile 265
# Running for tile 266
# Running for tile 267
# Running for tile 268
# Running for tile 269
# Running for tile 270
# Running for tile 271
# Running for tile 272
# Running for tile 273
# Running for tile 274
# Running for tile 275
# Running for tile 276
# Running for tile 277
# Running for tile 278
# Running for tile 279
# Running for tile 280
# Running for tile 281
# Running for tile 282
# Running for tile 283
# Running for tile 284
# Running for tile 285
# Running for tile 286
# Running for tile 287
# Running for tile 288
# Running for tile 289
# Running for tile 290
# Running for tile 291
# Running for tile 292
# Running for tile 293
# Running for tile 294
# Running for tile 295
# Running for tile 296
# Running for tile 297
# Running for tile 298
# Running for tile 299
# Running for tile 300
# Running for tile 301
# Running for tile 302
# Running for tile 303
# Running for tile 304
# Running for tile 305
# Running for tile 306
# Running for tile 307
# Running for tile 308
# Running for tile 309
# Running for tile 310
# Running for tile 311
# Running for tile 312
# Running for tile 313
# Running for tile 314
# Running for tile 315
# Running for tile 316
# Running for tile 317
# Running for tile 318
# Running for tile 319
# Running for tile 320
# Running for tile 321
# Running for tile 322
# Running for tile 323
# Running for tile 324
# Running for tile 325
# Running for tile 326
# Running for tile 327
# Running for tile 328
# Running for tile 329
# Running for tile 330
# Running for tile 331
# Running for tile 332
# Running for tile 333
# Running for tile 334
# Running for tile 335
# Running for tile 336
# Running for tile 337
# Running for tile 338
# Running for tile 339
# Running for tile 340
# Running for tile 341
# Running for tile 342
# Running for tile 343
# Running for tile 344
# Running for tile 345
# Running for tile 346
# Running for tile 347
# Running for tile 348
# Running for tile 349
# Running for tile 350
# Running for tile 351
# Running for tile 352
# Running for tile 353
# Running for tile 354
# Running for tile 355
# Running for tile 356
# Running for tile 357
# Running for tile 358
# Running for tile 359
# Running for tile 360
# Running for tile 361
# Running for tile 362
# Running for tile 363
# Running for tile 364
# Running for tile 365
# Running for tile 366
# Running for tile 367
# Running for tile 368
# Running for tile 369
# Running for tile 370
# Running for tile 371
# Running for tile 372
# Running for tile 373
# Running for tile 374
# Running for tile 375
# Running for tile 376
# Running for tile 377
# Running for tile 378
# Running for tile 379
# Running for tile 380
# Running for tile 381
# Running for tile 382
# Running for tile 383
# Running for tile 384
# Running for tile 385
# Running for tile 386
# Running for tile 387
# Running for tile 388
# Running for tile 389
# Running for tile 390
# Running for tile 391
# Running for tile 392
# Running for tile 393
# Running for tile 394
# Running for tile 395
# Running for tile 396
# Running for tile 397
# Running for tile 398
# Running for tile 399
# Running for tile 400
# Running for tile 401
# Running for tile 402
# Running for tile 403
# Running for tile 404
# Running for tile 405
# Running for tile 406
# Running for tile 407
# Running for tile 408
# Running for tile 409
# Running for tile 410
# Running for tile 411
# Running for tile 412
# Running for tile 413
# Running for tile 414
# Running for tile 415
# Running for tile 416
# Running for tile 417
# Running for tile 418
# Running for tile 419
# Running for tile 420
# Running for tile 421
# Running for tile 422
# Running for tile 423
# Running for tile 424
# Running for tile 425
# Running for tile 426
# Running for tile 427
# Running for tile 428
# Running for tile 429
# Running for tile 430
# Running for tile 431
# Running for tile 432
# Running for tile 433
# Running for tile 434
# Running for tile 435
# Running for tile 436
# Running for tile 437
# Running for tile 438
# Running for tile 439
# Running for tile 440
# Running for tile 441
# Running for tile 442
# Running for tile 443
# Running for tile 444
# Running for tile 445
# Running for tile 446
# Running for tile 447
# Running for tile 448
# Running for tile 449
# Running for tile 450
# Running for tile 451
# Running for tile 452
# Running for tile 453
# Running for tile 454
# Running for tile 455
# Running for tile 456
# Running for tile 457
# Running for tile 458
# Running for tile 459
# Running for tile 460
# Running for tile 461
# Running for tile 462
# Running for tile 463
# Running for tile 464
# Running for tile 465
# Running for tile 466
# Running for tile 467
# Running for tile 468
# Running for tile 469
# Running for tile 470
# Running for tile 471
# Running for tile 472
# Running for tile 473
# Running for tile 474
# Running for tile 475
# Running for tile 476
# Running for tile 477
# Running for tile 478
# Running for tile 479
# Running for tile 480
# Running for tile 481
# Running for tile 482
# Running for tile 483
# Running for tile 484
# Running for tile 485
# Running for tile 486
# Running for tile 487
# Running for tile 488
# Running for tile 489
# Running for tile 490
# Running for tile 491
# Running for tile 492
# Running for tile 493
# Running for tile 494
# Running for tile 495
# Running for tile 496
# Running for tile 497
# Running for tile 498
# Running for tile 499
# Running for tile 500
# Running for tile 501
# Running for tile 502
# Running for tile 503
# Running for tile 504
# Running for tile 505
# Running for tile 506
# Running for tile 507
# Running for tile 508
# Running for tile 509
# Running for tile 510
# Running for tile 511
# Running for tile 512
# Running for tile 513
# Running for tile 514
# Running for tile 515
# Running for tile 516
# Running for tile 517
# Running for tile 518
# Running for tile 519
# Running for tile 520
# Running for tile 521
# Running for tile 522
# Running for tile 523
# Running for tile 524
# Running for tile 525
# Running for tile 526
# Running for tile 527
# Running for tile 528
# Running for tile 529
# Running for tile 530
# Running for tile 531
# Running for tile 532
# Running for tile 533
# Running for tile 534
# Running for tile 535
# Running for tile 536
# Running for tile 537
# Running for tile 538
# Running for tile 539
# Running for tile 540
# Running for tile 541
# Running for tile 542
# Running for tile 543
# Running for tile 544
# Running for tile 545
# Running for tile 546
# Running for tile 547
# Running for tile 548
# Running for tile 549
# Running for tile 550
# Running for tile 551
# Running for tile 552
# Running for tile 553
# Running for tile 554
# Running for tile 555
# Running for tile 556
# Running for tile 557
# Running for tile 558
# Running for tile 559
# Running for tile 560
# Running for tile 561
# Running for tile 562
# Running for tile 563
# Running for tile 564
# Running for tile 565
# Running for tile 566
# Running for tile 567
# Running for tile 568
# Running for tile 569
# Running for tile 570
# Running for tile 571
# Running for tile 572
# Running for tile 573
# Running for tile 574
# Running for tile 575
# Running for tile 576
# Running for tile 577
# Running for tile 578
# Running for tile 579
# Running for tile 580
# Running for tile 581
# Running for tile 582
# Running for tile 583
# Running for tile 584
# Running for tile 585
# Running for tile 586
# Running for tile 587
# Running for tile 588
# Running for tile 589
# Running for tile 590
# Running for tile 591
# Running for tile 592
# Running for tile 593
# Running for tile 594
# Running for tile 595
# Running for tile 596
# Running for tile 597
# Running for tile 598
# Running for tile 599
# Running for tile 600
# Running for tile 601
# Running for tile 602
# Running for tile 603
# Running for tile 604
# Running for tile 605
# Running for tile 606
# Running for tile 607
# Running for tile 608
# Running for tile 609
# Running for tile 610
# Running for tile 611
# Running for tile 612
# Running for tile 613
# Running for tile 614
# Running for tile 615
# Running for tile 616
# Running for tile 617
# Running for tile 618
# Running for tile 619
# Running for tile 620
# Running for tile 621
# Running for tile 622
# Running for tile 623
# Running for tile 624
# Running for tile 625
# Running for tile 626
# Running for tile 627
# Running for tile 628
# Running for tile 629
# Running for tile 630
# Running for tile 631
# Running for tile 632
# Running for tile 633
# Running for tile 634
# Running for tile 635
# Running for tile 636
# Running for tile 637
# Running for tile 638
# Running for tile 639
# Running for tile 640
# Running for tile 641
# Running for tile 642
# Running for tile 643
# Running for tile 644
# Running for tile 645
# Running for tile 646
# Running for tile 647
# Running for tile 648
# Running for tile 649
# Running for tile 650
# Running for tile 651
# Running for tile 652
# Running for tile 653
# Running for tile 654
# Running for tile 655
# Running for tile 656
# Running for tile 657
# Running for tile 658
# Running for tile 659
# Running for tile 660
# Running for tile 661
# Running for tile 662
# Running for tile 663
# Running for tile 664
# Running for tile 665
# Running for tile 666
# Running for tile 667
# Running for tile 668
# Running for tile 669
# Running for tile 670
# Running for tile 671
# Running for tile 672
# Running for tile 673
# Running for tile 674
# Running for tile 675
# Running for tile 676
# Running for tile 677
# Running for tile 678
# Running for tile 679
# Running for tile 680
# Running for tile 681
# Running for tile 682
# Running for tile 683
# Running for tile 684
# Running for tile 685
# Running for tile 686
# Running for tile 687
# Running for tile 688
# Running for tile 689
# Running for tile 690
# Running for tile 691
# Running for tile 692
# Running for tile 693
# Running for tile 694
# Running for tile 695
# Running for tile 696
# Running for tile 697
# Running for tile 698
# Running for tile 699
# Running for tile 700
# Running for tile 701
# Running for tile 702
# Running for tile 703
# Running for tile 704
# Running for tile 705
# Running for tile 706
# Running for tile 707
# Running for tile 708
# Running for tile 709
# Running for tile 710
# Running for tile 711
# Running for tile 712
# Running for tile 713
# Running for tile 714
# Running for tile 715
# Running for tile 716
# Running for tile 717
# Running for tile 718
# Running for tile 719
# Running for tile 720
# Running for tile 721
# Running for tile 722
# Running for tile 723
# Running for tile 724
# Running for tile 725
# Running for tile 726
# Running for tile 727
# Running for tile 728
# Running for tile 729
# Running for tile 730
# Running for tile 731
# Running for tile 732
# Running for tile 733
# Running for tile 734
# Running for tile 735
# Running for tile 736
# Running for tile 737
# Running for tile 738
# Running for tile 739
# Running for tile 740
# Running for tile 741
# Running for tile 742
# Running for tile 743
# Running for tile 744
# Running for tile 745
# Running for tile 746
# Running for tile 747
# Running for tile 748
# Running for tile 749
# Running for tile 750
# Running for tile 751
# Running for tile 752
# Running for tile 753
# Running for tile 754
# Running for tile 755
# Running for tile 756
# Running for tile 757
# Running for tile 758
# Running for tile 759
# Running for tile 760
# Running for tile 761
# Running for tile 762
# Running for tile 763
# Running for tile 764
# Running for tile 765
# Running for tile 766
# Running for tile 767
# Running for tile 768
# Running for tile 769
# Running for tile 770
# Running for tile 771
# Running for tile 772
# Running for tile 773
# Running for tile 774
# Running for tile 775
# Running for tile 776
# Running for tile 777
# Running for tile 778
# Running for tile 779
# Running for tile 780
# Running for tile 781
# Running for tile 782
# Running for tile 783
# Running for tile 784
# Running for tile 785
# Running for tile 786
# Running for tile 787
# Running for tile 788
# Running for tile 789
# Running for tile 790
# Running for tile 791
# Running for tile 792
# Running for tile 793
# Running for tile 794
# Running for tile 795
# Running for tile 796
# Running for tile 797
# Running for tile 798
# Running for tile 799
# Running for tile 800
# Running for tile 801
# Running for tile 802
# Running for tile 803
# Running for tile 804
# Running for tile 805
# Running for tile 806
# Running for tile 807
# Running for tile 808
# Running for tile 809
# Running for tile 810
# Running for tile 811
# Running for tile 812
# Running for tile 813
# Running for tile 814
# Running for tile 815
# Running for tile 816
# Running for tile 817
# Running for tile 818
# Running for tile 819
# Running for tile 820
# Running for tile 821
# Running for tile 822
# Running for tile 823
# Running for tile 824
# Running for tile 825
# Running for tile 826
# Running for tile 827
# Running for tile 828
# Running for tile 829
# Running for tile 830
# Running for tile 831
# Running for tile 832
# Running for tile 833
# Running for tile 834
# Running for tile 835
# Running for tile 836
# Running for tile 837
# Running for tile 838
# Running for tile 839
# Running for tile 840
# Running for tile 841
# Running for tile 842
# Running for tile 843
# Running for tile 844
# Running for tile 845
# Running for tile 846
# Running for tile 847
# Running for tile 848
# Running for tile 849
# Running for tile 850
# Running for tile 851
# Running for tile 852
# Running for tile 853
# Running for tile 854
# Running for tile 855
# Running for tile 856
# Running for tile 857
# Running for tile 858
# Running for tile 859
# Running for tile 860
# Running for tile 861
# Running for tile 862
# Running for tile 863
# Running for tile 864
# Running for tile 865
# Running for tile 866
# Running for tile 867
# Running for tile 868
# Running for tile 869
# Running for tile 870
# Running for tile 871
# Running for tile 872
# Running for tile 873
# Running for tile 874
# Running for tile 875
# Running for tile 876
# Running for tile 877
# Running for tile 878
# Running for tile 879
# Running for tile 880
# Running for tile 881
# Running for tile 882
# Running for tile 883
# Running for tile 884
# Running for tile 885
# Running for tile 886
# Running for tile 887
# Running for tile 888
# Running for tile 889
# Running for tile 890
# Running for tile 891
# Running for tile 892
# Running for tile 893
# Running for tile 894
# Running for tile 895
# Running for tile 896
# Running for tile 897
# Running for tile 898
# Running for tile 899
# Running for tile 900
# Running for tile 901
# Running for tile 902
# Running for tile 903
# Running for tile 904
# Running for tile 905
# Running for tile 906
# Running for tile 907
# Running for tile 908
# Running for tile 909
# Running for tile 910
# Running for tile 911
# Running for tile 912
# Running for tile 913
# Running for tile 914
# Running for tile 915
# Running for tile 916
# Running for tile 917
# Running for tile 918
# Running for tile 919
# Running for tile 920
# Running for tile 921
# Running for tile 922
# Running for tile 923
# Running for tile 924
# Running for tile 925
# Running for tile 926
# Running for tile 927
# Running for tile 928
# Running for tile 929
# Running for tile 930
# Running for tile 931
# Running for tile 932
# Running for tile 933
# Running for tile 934
# Running for tile 935
# Running for tile 936
# Running for tile 937
# Running for tile 938
# Running for tile 939
# Running for tile 940
# Running for tile 941
# Running for tile 942
# Running for tile 943
# Running for tile 944
# Running for tile 945
# Running for tile 946
# Running for tile 947
# Running for tile 948
# Running for tile 949
# Running for tile 950
# Running for tile 951
# Running for tile 952
# Running for tile 953
# Running for tile 954
# Running for tile 955
# Running for tile 956
# Running for tile 957
# Running for tile 958
# Running for tile 959
# Running for tile 960
# Running for tile 961
# Running for tile 962
# Running for tile 963
# Running for tile 964
# Running for tile 965
# Running for tile 966
# Running for tile 967
# Running for tile 968
# Running for tile 969
# Running for tile 970
# Running for tile 971
# Running for tile 972
# Running for tile 973
# Running for tile 974
# Running for tile 975
# Running for tile 976
# Running for tile 977
# Running for tile 978
# Running for tile 979
# Running for tile 980
# Running for tile 981
# Running for tile 982
# Running for tile 983
# Running for tile 984
# Running for tile 985
# Running for tile 986
# Running for tile 987
# Running for tile 988
# Running for tile 989
# Running for tile 990
# Running for tile 991
# Running for tile 992
# Running for tile 993
# Running for tile 994
# Running for tile 995
# Running for tile 996
# Running for tile 997
# Running for tile 998
# Running for tile 999
# Running for tile 1000
# Running for tile 1001
# Running for tile 1002
# Running for tile 1003
# Running for tile 1004
# Running for tile 1005
# Running for tile 1006
# Running for tile 1007
# Running for tile 1008
# Running for tile 1009
# Running for tile 1010
# Running for tile 1011
# Running for tile 1012
# Running for tile 1013
# Running for tile 1014
# Running for tile 1015
# Running for tile 1016
# Running for tile 1017
# Running for tile 1018
# Running for tile 1019
# Running for tile 1020
# Running for tile 1021
# Running for tile 1022
# Running for tile 1023
# Running for tile 1024
# Running for tile 1025
# Running for tile 1026
# Running for tile 1027
# Running for tile 1028
# Running for tile 1029
# Running for tile 1030
# Running for tile 1031
# Running for tile 1032
# Running for tile 1033
# Running for tile 1034
# Running for tile 1035
# Running for tile 1036
# Running for tile 1037
# Running for tile 1038
# Running for tile 1039
# Running for tile 1040
# Running for tile 1041
# Running for tile 1042
# Running for tile 1043
# Running for tile 1044
# Running for tile 1045
# Running for tile 1046
# Running for tile 1047
# Running for tile 1048
# Running for tile 1049
# Running for tile 1050
# Running for tile 1051
# Running for tile 1052
# Running for tile 1053
# Running for tile 1054
# Running for tile 1055
# Running for tile 1056
# Running for tile 1057
# Running for tile 1058
# Running for tile 1059
# Running for tile 1060
# Running for tile 1061
# Running for tile 1062
# Running for tile 1063
# Running for tile 1064
# Running for tile 1065
# Running for tile 1066
# Running for tile 1067
# Running for tile 1068
# Running for tile 1069
# Running for tile 1070
# Running for tile 1071
# Running for tile 1072
# Running for tile 1073
# Running for tile 1074
# Running for tile 1075
# Running for tile 1076
# Running for tile 1077
# Running for tile 1078
# Running for tile 1079
# Running for tile 1080
# Running for tile 1081
# Running for tile 1082
# Running for tile 1083
# Running for tile 1084
# Running for tile 1085
# Running for tile 1086
# Running for tile 1087
# Running for tile 1088
# Running for tile 1089
# Running for tile 1090
# Running for tile 1091
# Running for tile 1092
# Running for tile 1093
# Running for tile 1094
# Running for tile 1095
# Running for tile 1096
# Running for tile 1097
# Running for tile 1098
# Running for tile 1099
# Running for tile 1100
# Running for tile 1101
# Running for tile 1102
# Running for tile 1103
# Running for tile 1104
# Running for tile 1105
# Running for tile 1106
# Running for tile 1107
# Running for tile 1108
# Running for tile 1109
# Running for tile 1110
# Running for tile 1111
# Running for tile 1112
# Running for tile 1113
# Running for tile 1114
# Running for tile 1115
# Running for tile 1116
# Running for tile 1117
# Running for tile 1118
# Running for tile 1119
# Running for tile 1120
# Running for tile 1121
# Running for tile 1122
# Running for tile 1123
# Running for tile 1124
# Running for tile 1125
# Running for tile 1126
# Running for tile 1127
# Running for tile 1128
# Running for tile 1129
# Running for tile 1130
# Running for tile 1131
# Running for tile 1132
# Running for tile 1133
# Running for tile 1134
# Running for tile 1135
# Running for tile 1136
# Running for tile 1137
# Running for tile 1138
# Running for tile 1139
# Running for tile 1140
# Running for tile 1141
# Running for tile 1142
# Running for tile 1143
# Running for tile 1144
# Running for tile 1145
# Running for tile 1146
# Running for tile 1147
# Running for tile 1148
# Running for tile 1149
# Running for tile 1150
# Running for tile 1151
# Running for tile 1152
# Running for tile 1153
# Running for tile 1154
# Running for tile 1155
# Running for tile 1156
# Running for tile 1157
# Running for tile 1158
# Running for tile 1159
# Running for tile 1160
# Running for tile 1161
# Running for tile 1162
# Running for tile 1163
# Running for tile 1164
# Running for tile 1165
# Running for tile 1166
# Running for tile 1167
# Running for tile 1168
# Running for tile 1169
# Running for tile 1170
# Running for tile 1171
# Running for tile 1172
# Running for tile 1173
# Running for tile 1174
# Running for tile 1175
# Running for tile 1176
# Running for tile 1177
# Running for tile 1178
# Running for tile 1179
# Running for tile 1180
# Running for tile 1181
# Running for tile 1182
# Running for tile 1183
# Running for tile 1184
# Running for tile 1185
# Running for tile 1186
# Running for tile 1187
# Running for tile 1188
# Running for tile 1189
# Running for tile 1190
# Running for tile 1191
# Running for tile 1192
# Running for tile 1193
# Running for tile 1194
# Running for tile 1195
# Running for tile 1196
# Running for tile 1197
# Running for tile 1198
# Running for tile 1199

# %%
def get_IBM(n_list, s_list):
  length = len(s_list)
  ibm_list = np.zeros(shape=(length,513))
  for i in range(length):
    ibm = np.zeros(len(s_list[i]))
    ibm[s_list[i] > n_list[i]] = 1
    ibm_list[i] = ibm
  return ibm_list

# %%
ibm = get_IBM(train_n_list, train_s_list)

# %%
ibm = np.expand_dims(ibm, 2)
train_x_list = np.expand_dims(train_x_list, 2)

# %%
BATCH = 10
train_loader = torch.utils.data.DataLoader(train_x_list, batch_size=BATCH)
test_loader = torch.utils.data.DataLoader(ibm, batch_size=BATCH)

# %%
#Ref : https://nipunbatra.github.io/blog/2018/denoising.html
class GRU(nn.Module):
    
#     def step(self, pred):
#         greater = pred >=0.5
#         less = pred < 0.5
#         pred[greater] = 1
#         pred[less] = 0
#         return pred
  
    def __init__(self, input_size, hidden_size):
        super(GRU, self).__init__()
        self.rnn = nn.LSTM(input_size=input_size, hidden_size=hidden_size)
        self.linear = nn.Linear(hidden_size, 1)
        self.act = torch.sigmoid
        
    def forward(self, x):
        pred, hidden = self.rnn(x, None)
        pred = self.act(self.linear(pred)).view(pred.data.shape[0], -1, 1)
        
#         greater = pred >=0.5
#         less = pred < 0.5
#         pred[greater] = 1
#         pred[less] = 0
        return pred
model = GRU(1, 3).cuda()
print(model)
# Out:
# GRU(
#   (rnn): LSTM(1, 3)
#   (linear): Linear(in_features=3, out_features=1, bias=True)
# )

# %%
loss_function= nn.MSELoss()
para = model.parameters()
optimizer = torch.optim.Adam(params=para, lr=0.001)
loss_list = []
x_train = train_x_list
y_train = ibm
for i in range(epochs):            
    model_input = Variable(torch.Tensor(x_train.reshape((x_train.shape[0], -1, 1))), requires_grad=True).cuda()
    target = Variable(torch.Tensor(y_train.reshape((y_train.shape[0], -1, 1))) ).cuda()
    optimizer.zero_grad()
    network_output  = model(model_input)
    loss = loss_function(network_output , target)
    loss.backward()
    optimizer.step()
    loss_list.append(loss.data.cpu().numpy())
plt.plot(range(epochs), loss_list)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-c170fe8adaa2> in <module>()
#      12     network_output  = model(model_input)
#      13     loss = loss_function(network_output , target)
# ---> 14     loss.backward()
#      15     optimizer.step()
#      16     loss_list.append(loss.data.cpu().numpy())
#
# /usr/local/lib/python3.6/dist-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     100                 products. Defaults to ``False``.
#     101         """
# --> 102         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     103
#     104     def register_hook(self, hook):
#
# /usr/local/lib/python3.6/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      88     Variable._execution_engine.run_backward(
#      89         tensors, grad_tensors, retain_graph, create_graph,
# ---> 90         allow_unreachable=True)  # allow_unreachable flag
#      91
#      92
#
# KeyboardInterrupt:

# %%
# validation_dirty_files, validation_speech_files, validation_noise_files = get_files(validation_folder)
test_dirty_files = get_files(test_folder, True)

# %% [markdown]
# **--------------------------------------------------------------------------------------------------Validation Begins-----------------------------------------------------**

# %%
# validation_s_list, validation_n_list, validation_x_list = get_processed_lists(validation_dirty_files, validation_speech_files, validation_noise_files)
test_x_list, test_x_complex = get_processed_lists(test_dirty_files, None, None, True)
x_list = test_x_list

# %%
# # doing for one file
# x, sr=librosa.load('tr/trx0000.wav', sr=None)
# X=librosa.stft(x, n_fft=1024, hop_length=512)
# #     for speech files
# s, sr=librosa.load('tr/trs0000.wav', sr=None)
# S=librosa.stft(s, n_fft=1024, hop_length=512)
# #     for noise files
# n, sr=librosa.load('tr/trn0000.wav', sr=None)
# N=librosa.stft(n, n_fft=1024, hop_length=512)

# %%
# x_list = np.zeros(shape=(513,1))
# s_list = np.zeros(shape=(513,1))
# n_list = np.zeros(shape=(513,1))

# %%
# x_list.shape
# x_list[:,0]
# print(x_abs.shape)

# %%
# x_abs = np.abs(X)
# s_abs = np.abs(S)
# n_abs = np.abs(N)

# print(x_abs.shape)
# print(s_abs.shape)
# print(n_abs.shape)
    
# print(x_list.shape)
# if x_list.shape[1] == 1:
#   print('here')
#   x_list = x_abs
#   s_list = s_abs
#   n_list = n_abs
# else:  
#   x_list = np.append(x_list, x_abs,1)
#   s_list = np.append(s_list, s_abs,1)
#   n_list = np.append(n_list, n_abs,1)

# print(x_list.shape)
# print(n_list.shape)
# print(x_list.shape)

# s_list = s_list.T
# n_list = n_list.T
# x_list = x_list.T

# %%
model_input = Variable(torch.Tensor(x_list.reshape((x_list.shape[0], -1, 1))))
prediction = model(model_input.cuda())

# %%
prediction = 1 * (prediction > 0.5)

# %%
y = prediction.detach().cpu().numpy()
print(np.max(y))
print(np.min(y))

# %%
print(test_x_complex.shape)
print(y.shape)
result = np.multiply(test_x_complex,y.reshape(y.shape[0],dimension))
print(result.shape)

# %%
print(test_x_complex.shape)
print(x_list.shape)

# %%
result.dtype

# %%
# m_input =  model_input.detach().numpy()

# spec = (m_input.reshape(dimension,result.shape[0]) / np.abs(m_input).reshape(dimension,result.shape[0])) * result.T

# %%
# print(spec.shape)

# %%
# spec_istft = librosa.istft(spec, hop_length=512)
result_istft = librosa.istft(result.T, hop_length=512)

# %%
# print(spec_istft.shape)
print(result_istft.shape)
print(result_istft[:10000].shape)

# %%
# print(srs)
# print(srn)
# print(srx)
# librosa.output.write_wav('validation2.wav', spec_istft, srs)
librosa.output.write_wav('validation_result.wav', result_istft[:200000], srs)

# %%
# ipd.Audio('validation2.wav')

# %%
ipd.Audio('validation_result.wav')

# %%
s = test_x_complex
print(s.shape)
y = y.reshape(result.shape[0], dimension)
print(y.shape)
print(np.max(y))

# %%
# print(10*np.log10(np.sum(np.square(test_x_complex)/(np.sum(np.square(np.subtract(test_x_complex ,y)))))))
